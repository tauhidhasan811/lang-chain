# %%
from dotenv import load_dotenv
from transformers import pipeline
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint, HuggingFacePipeline

# %%
pipe = pipeline(
    "text-generation",
    model="microsoft/UserLM-8b"
)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   7%|7         | 157M/2.20G [00:00<?, ?B/s]
# Exception in thread Thread-3:
# Traceback (most recent call last):
#   File "C:\Users\Tahid Hasan\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\tqdm\_monitor.py", line 84, in run
#     instance.refresh(nolock=True)
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\tqdm\std.py", line 1347, in refresh
#     self.display()
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\tqdm\notebook.py", line 171, in display
#     rtext.value = right
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\traitlets\traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\traitlets\traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\traitlets\traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\ipywidgets\widgets\widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\ipywidgets\widgets\widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\ipywidgets\widgets\widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\comm\base_comm.py", line 144, in send
#     self.publish_msg(
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\ipykernel\comm\comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\ipykernel\kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x000001DFD5874400>
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Device set to use cpu

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFacePipeline(pipeline=pipe)
response = llm.invoke("What is the capital of Bangladesh?")
print(response)
# Out:
# What is the capital of Bangladesh?

# %%
llm = HuggingFaceEndpoint(pipeline = pipe)
# Out:
# WARNING! pipeline is not default parameter.
#                     pipeline was transferred to model_kwargs.
#                     Please make sure that pipeline is what you intended.
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 llm = HuggingFaceEndpoint(pipeline = pipe)
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\langchain_core\load\serializable.py:113, in Serializable.__init__(self, *args, **kwargs)
#     111 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     112     """"""  # noqa: D419  # Intentional blank docstring
# --> 113     super().__init__(*args, **kwargs)
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for HuggingFaceEndpoint
#   Value error, Please specify a `model` or an `endpoint_url` or a `repo_id` for the model. [type=value_error, input_value={'model_kwargs': {'pipeli...3D2470>}, 'model': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error

# %%
model = ChatHuggingFace(llm = llm)

# %%
t = model.invoke('what is the capital of Bangladesh').content
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t = model.invoke('what is the capital of Bangladesh').content
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:379, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     365 @override
#     366 def invoke(
#     367     self,
#    (...)
#     372     **kwargs: Any,
#     373 ) -> AIMessage:
#     374     config = ensure_config(config)
#     375     return cast(
#     376         "AIMessage",
#     377         cast(
#     378             "ChatGeneration",
# --> 379             self.generate_prompt(
#     380                 [self._convert_input(input)],
#     381                 stop=stop,
#     382                 callbacks=config.get("callbacks"),
#     383                 tags=config.get("tags"),
#     384                 metadata=config.get("metadata"),
#     385                 run_name=config.get("run_name"),
#     386                 run_id=config.pop("run_id", None),
#     387                 **kwargs,
#     388             ).generations[0][0],
#     389         ).message,
#     390     )
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1088, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1079 @override
#    1080 def generate_prompt(
#    1081     self,
#    (...)
#    1085     **kwargs: Any,
#    1086 ) -> LLMResult:
#    1087     prompt_messages = [p.to_messages() for p in prompts]
# -> 1088     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:903, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     900 for i, m in enumerate(input_messages):
#     901     try:
#     902         results.append(
# --> 903             self._generate_with_cache(
#     904                 m,
#     905                 stop=stop,
#     906                 run_manager=run_managers[i] if run_managers else None,
#     907                 **kwargs,
#     908             )
#     909         )
#     910     except BaseException as e:
#     911         if run_managers:
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1192, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1190     result = generate_from_stream(iter(chunks))
#    1191 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1192     result = self._generate(
#    1193         messages, stop=stop, run_manager=run_manager, **kwargs
#    1194     )
#    1195 else:
#    1196     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\langchain_huggingface\chat_models\huggingface.py:584, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     577     message_dicts, params = self._create_message_dicts(messages, stop)
#     578     params = {
#     579         "stop": stop,
#     580         **params,
#     581         **({"stream": stream} if stream is not None else {}),
#     582         **kwargs,
#     583     }
# --> 584     answer = self.llm.client.chat_completion(messages=message_dicts, **params)
#     585     return self._create_chat_result(answer)
#     586 llm_input = self._to_chat_prompt(messages)
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\huggingface_hub\inference\_client.py:882, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     879 payload_model = model or self.model
#     881 # Get the provider helper
# --> 882 provider_helper = get_provider_helper(
#     883     self.provider,
#     884     task="conversational",
#     885     model=model_id_or_url
#     886     if model_id_or_url is not None and model_id_or_url.startswith(("http://", "https://"))
#     887     else payload_model,
#     888 )
#     890 # Prepare the payload
#     891 parameters = {
#     892     "model": payload_model,
#     893     "frequency_penalty": frequency_penalty,
#    (...)
#     910     **(extra_body or {}),
#     911 }
#
# File c:\Users\Tahid Hasan\Desktop\lang_chain\venv\lib\site-packages\huggingface_hub\inference\_providers\__init__.py:212, in get_provider_helper(provider, task, model)
#     210         raise ValueError("Specifying a model is required when provider is 'auto'")
#     211     provider_mapping = _fetch_inference_provider_mapping(model)
# --> 212     provider = next(iter(provider_mapping)).provider
#     214 provider_tasks = PROVIDERS.get(provider)  # type: ignore
#     215 if provider_tasks is None:
#
# StopIteration:

# %%
t
# Out:
# 'The capital of Bangladesh is **Dhaka**.'
